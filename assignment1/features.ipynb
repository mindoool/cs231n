# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\features.py:124: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   cx / 2::cx, cy / 2::cy].T
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = 10**np.random.uniform(-6, -3, 200)
regularization_strengths = 10**np.random.uniform(-5, 5, 200)

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################

for lr, reg in zip(learning_rates, regularization_strengths):
    svm = LinearSVM()
    svm.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=1500, verbose=False)

    y_train_pred = svm.predict(X_train_feats)
    y_val_pred = svm.predict(X_val_feats)

    results[(lr,reg)] = (np.mean(y_train == y_train_pred), np.mean(y_val == y_val_pred))

    if best_val < np.mean(y_val == y_val_pred):
        best_val = np.mean(y_val == y_val_pred)
        best_svm = svm

################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:89: RuntimeWarning: overflow encountered in double_scalars
#   loss += reg * np.sum(W * W)
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:89: RuntimeWarning: overflow encountered in multiply
#   loss += reg * np.sum(W * W)
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:102: RuntimeWarning: overflow encountered in multiply
#   dW += 2 * W * reg
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:87: RuntimeWarning: invalid value encountered in maximum
#   forward_margins = np.maximum(0, margins)
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:92: RuntimeWarning: invalid value encountered in less
#   dS[margins < 0] = 1
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:95: RuntimeWarning: invalid value encountered in greater
#   dS[margins > 0] = 1
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:96: RuntimeWarning: invalid value encountered in less
#   dS[margins < 0] = 0
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_classifier.py:74: RuntimeWarning: invalid value encountered in subtract
#   self.W = self.W - learning_rate * grad
# D:\Dropbox\CS231n\Assignment\assignment1\cs231n\classifiers\linear_svm.py:83: RuntimeWarning: invalid value encountered in subtract
#   margins = scores - scores_correct.reshape((num_train, 1)) + 1
# lr 1.066092e-06 reg 1.085047e+04 train accuracy: 0.413653 val accuracy: 0.411000
# lr 1.138744e-06 reg 1.333541e+00 train accuracy: 0.268898 val accuracy: 0.259000
# lr 1.140123e-06 reg 3.998008e-02 train accuracy: 0.257633 val accuracy: 0.246000
# lr 1.181306e-06 reg 1.778336e+02 train accuracy: 0.321980 val accuracy: 0.325000
# lr 1.205230e-06 reg 2.570865e-03 train accuracy: 0.279224 val accuracy: 0.290000
# lr 1.233092e-06 reg 2.958053e-05 train accuracy: 0.282020 val accuracy: 0.288000
# lr 1.234847e-06 reg 2.528463e+02 train accuracy: 0.333347 val accuracy: 0.342000
# lr 1.259989e-06 reg 5.000921e-05 train accuracy: 0.294265 val accuracy: 0.293000
# lr 1.260154e-06 reg 2.959050e-02 train accuracy: 0.285939 val accuracy: 0.288000
# lr 1.293135e-06 reg 2.092976e-03 train accuracy: 0.281918 val accuracy: 0.291000
# lr 1.295247e-06 reg 6.043832e-02 train accuracy: 0.280122 val accuracy: 0.261000
# lr 1.312893e-06 reg 4.287521e-03 train accuracy: 0.309102 val accuracy: 0.305000
# lr 1.358190e-06 reg 1.670758e+00 train accuracy: 0.280469 val accuracy: 0.269000
# lr 1.401339e-06 reg 2.387130e-01 train accuracy: 0.297551 val accuracy: 0.296000
# lr 1.413869e-06 reg 1.570537e-04 train accuracy: 0.279776 val accuracy: 0.256000
# lr 1.429906e-06 reg 8.723499e+01 train accuracy: 0.309857 val accuracy: 0.328000
# lr 1.433412e-06 reg 3.936393e-02 train accuracy: 0.284796 val accuracy: 0.277000
# lr 1.517535e-06 reg 4.993640e-01 train accuracy: 0.296551 val accuracy: 0.292000
# lr 1.650078e-06 reg 4.193611e-01 train accuracy: 0.293510 val accuracy: 0.304000
# lr 1.657399e-06 reg 2.654866e-01 train accuracy: 0.314612 val accuracy: 0.333000
# lr 1.658060e-06 reg 2.258864e+01 train accuracy: 0.327469 val accuracy: 0.331000
# lr 1.672519e-06 reg 1.147822e+01 train accuracy: 0.318061 val accuracy: 0.335000
+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.311568e-04 reg 4.350117e-04 train accuracy: 0.498204 val accuracy: 0.488000
# lr 8.362174e-04 reg 4.732264e-01 train accuracy: 0.490306 val accuracy: 0.479000
# lr 8.780321e-04 reg 1.244226e+02 train accuracy: 0.397531 val accuracy: 0.391000
# lr 8.960676e-04 reg 1.831248e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.139906e-04 reg 2.847057e+03 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.610238e-04 reg 4.833799e-05 train accuracy: 0.500347 val accuracy: 0.484000
# lr 9.615124e-04 reg 2.545668e-01 train accuracy: 0.496082 val accuracy: 0.481000
# best validation accuracy achieved during cross-validation: 0.488000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.476

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

result = {}
best_val = -1
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
learning_rates = 10**np.random.uniform(-4, -0.5, 100)
regularization_strengths = 10**np.random.uniform(-60, -5, 100)

for lr, reg in zip(learning_rates, regularization_strengths):
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=100, batch_size=500,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, verbose=False)
    val_acc = (net.predict(X_val_feats) == y_val).mean()
    results[(lr,reg)] = val_acc
    
    print(lr, reg, val_acc)
    
    if best_val < val_acc:
        best_net = net
        best_val = val_acc
    
print(best_val)

for result in results:
    print("learning_rate: %s, regulariztion_rates: %s, acc= %s" %(result[0],result[1],results[result]))

print("Best Accuracy : %s" %best_val)


################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# 0.164489381045 4.21156234566e-26 0.189
# 0.000188653193168 1.15350910963e-06 0.191
# 0.00500896012519 1.39864708456e-07 0.22
# 0.00112904552236 2.71389022521e-38 0.221
# 0.000284768327055 3.54002443961e-35 0.221
# 0.0010180477016 5.25317035785e-25 0.222
# 0.000182819680376 1.10609936378e-31 0.222
# 0.139375864984 3.14444572147e-21 0.348
# 0.173820178096 1.36354618771e-49 0.442
# 0.00182985977298 8.23136788553e-30 0.446
# 0.00623347735857 1.08224567812e-10 0.45
# 0.027991475699 1.85374463715e-57 0.461
# 0.000118904671137 1.20449760015e-51 0.461
# 0.000227186150879 6.41919089343e-09 0.462
# 0.000584536719531 3.12653072531e-42 0.462
# 0.000320035148141 2.28665922494e-26 0.462
# 0.00366938433962 8.33807522765e-55 0.466
# 0.000518566952706 3.4083989612e-49 0.467
# 0.0122766158418 2.00261320152e-46 0.468
# 0.0361760921703 2.90705734111e-07 0.482
# 0.01600236245 2.01876496017e-26 0.486
# 0.000326681764459 7.74478384714e-06 0.488
# 0.0402280685581 4.04861203502e-28 0.483
# 0.13068293425 2.07771150778e-26 0.494
# 0.198201157551 2.37371044304e-14 0.509
# 0.0155473449642 2.41133990735e-41 0.519
# 0.0440467026663 5.74845073797e-52 0.522
# 0.0837962386065 5.36418657511e-32 0.527
# 0.0304284266879 1.72889869152e-17 0.525
# 0.000237476818489 9.91219671565e-55 0.524
# 0.0225116854465 3.0613089714e-07 0.53
# 0.000289714068171 5.49922651407e-12 0.531
# 0.137846442763 4.48755185195e-07 0.517
# 0.0112815222901 9.6884959558e-17 0.517
# 0.000820517178639 5.21623448159e-06 0.519
# 0.0148113151637 1.29165400817e-15 0.522
# 0.000615525441786 7.3326962894e-37 0.523
# 0.0393934767905 7.56656062059e-51 0.527
# 0.177856455067 4.25512612131e-36 0.533
# 0.0166981952484 2.96024708349e-08 0.538
# learning_rate: 0.00791025287311, regulariztion_rates: 4.36568876776e-19, acc= 0.516
# learning_rate: 1.44659248954e-05, regulariztion_rates: 1.73551042595e-42, acc= 0.384
# learning_rate: 0.000166438527779, regulariztion_rates: 9.72728928833e-41, acc= 0.556
# learning_rate: 0.000584536719531, regulariztion_rates: 3.12653072531e-42, acc= 0.462
# learning_rate: 0.0178759931566, regulariztion_rates: 4.51332077731e-37, acc= 0.297
# learning_rate: 0.00668472493512, regulariztion_rates: 2.51802414132e-22, acc= 0.515
# learning_rate: 0.00096151242083, regulariztion_rates: 0.254566773953, acc= (0.49608163265306121, 0.48099999999999998)
# learning_rate: 0.0014448033801, regulariztion_rates: 1.86498791995e-33, acc= 0.54
# learning_rate: 9.08790625744e-07, regulariztion_rates: 2.14032710902e-40, acc= 0.078
# learning_rate: 3.38253188011e-05, regulariztion_rates: 5.05950339109e-32, acc= 0.087
# learning_rate: 0.223592544715, regulariztion_rates: 1.12444571449e-49, acc= 0.573
# learning_rate: 0.00101554534765, regulariztion_rates: 4.99464160669e-30, acc= 0.536
# learning_rate: 2.49329722686e-06, regulariztion_rates: 0.00336413365613, acc= (0.35012244897959183, 0.33000000000000002)
# learning_rate: 0.0228872122243, regulariztion_rates: 3.62679281485e-58, acc= 0.593
# learning_rate: 1.99195178953e-05, regulariztion_rates: 0.0525976492273, acc= 0.079
# learning_rate: 0.0052337737492, regulariztion_rates: 6.84472734106e-06, acc= 0.491
# learning_rate: 0.00403390262964, regulariztion_rates: 4.28220834951e-42, acc= 0.078
# learning_rate: 0.011383659841, regulariztion_rates: 1.78243729556e-24, acc= 0.209
# learning_rate: 3.57736848197e-06, regulariztion_rates: 0.474826742527, acc= 0.079
# learning_rate: 1.84584163499e-05, regulariztion_rates: 8.62705025364, acc= (0.41259183673469385, 0.41599999999999998)
# learning_rate: 5.47800202416e-09, regulariztion_rates: 2.31605809905e-44, acc= 0.078
# learning_rate: 2.87763872106e-05, regulariztion_rates: 2.54494668391e-32, acc= 0.104
# learning_rate: 3.87819219851e-08, regulariztion_rates: 4.06830151001e-25, acc= 0.078
# learning_rate: 0.00990043215125, regulariztion_rates: 1.04244155973e-32, acc= 0.409
# learning_rate: 3.2796871912e-07, regulariztion_rates: 4.30158631902e-05, acc= 0.079
# learning_rate: 0.00467636350565, regulariztion_rates: 3.50034307918e-21, acc= 0.51
# learning_rate: 0.000183103305134, regulariztion_rates: 3.50088441466e-27, acc= 0.588
# learning_rate: 1.83116521223e-07, regulariztion_rates: 2.06096841175e-05, acc= 0.081
# learning_rate: 5.85389173545e-07, regulariztion_rates: 0.000326687622932, acc= 0.095
# learning_rate: 1.85308784116e-09, regulariztion_rates: 1.14307068815e-17, acc= 0.078
# learning_rate: 0.000138449493847, regulariztion_rates: 7.54146897864e-13, acc= 0.492
# learning_rate: 0.000170206368483, regulariztion_rates: 2.08735606723e-49, acc= 0.6
# learning_rate: 0.000205240942977, regulariztion_rates: 1.79203985657e-37, acc= 0.107
# learning_rate: 1.40653123819e-05, regulariztion_rates: 5.7051379746e-34, acc= 0.482
# learning_rate: 0.0423664406261, regulariztion_rates: 1.21233574265e-32, acc= 0.475
# learning_rate: 1.67251893513e-06, regulariztion_rates: 11.4782175645, acc= (0.3180612244897959, 0.33500000000000002)
# learning_rate: 0.00258635148577, regulariztion_rates: 8.33305342947e-31, acc= 0.52
# learning_rate: 2.25056014451e-05, regulariztion_rates: 4.80258592936e-40, acc= 0.515
# learning_rate: 0.000978885401166, regulariztion_rates: 6.71839128569e-47, acc= 0.536
# learning_rate: 9.82044981428e-07, regulariztion_rates: 2.57488729211e-21, acc= 0.078
# learning_rate: 7.64996967193e-07, regulariztion_rates: 0.0310354692368, acc= 0.08
# learning_rate: 2.44596211984e-08, regulariztion_rates: 1.38250850271e-09, acc= 0.078
# learning_rate: 0.000734894883164, regulariztion_rates: 4.15066572946e-06, acc= 0.485
# learning_rate: 0.0263530112245, regulariztion_rates: 2.72953516362e-45, acc= 0.224
# learning_rate: 1.34733579904e-05, regulariztion_rates: 989.769214696, acc= (0.40910204081632651, 0.40999999999999998)
# learning_rate: 2.92658416731e-05, regulariztion_rates: 4.92483067861e-29, acc= 0.421
# learning_rate: 0.000102706825725, regulariztion_rates: 2.35878095035e-52, acc= 0.538
# learning_rate: 2.23570063077e-06, regulariztion_rates: 4.75351321359, acc= (0.32983673469387753, 0.34000000000000002)
# learning_rate: 0.000721284282822, regulariztion_rates: 5.8274459996e-29, acc= 0.087
# learning_rate: 0.0005372127243, regulariztion_rates: 7.27111455323e-34, acc= 0.54
# learning_rate: 0.00100836805244, regulariztion_rates: 1.03456979524e-53, acc= 0.559
# learning_rate: 0.000181692969373, regulariztion_rates: 0.000182473646837, acc= (0.46785714285714286, 0.46200000000000002)
# learning_rate: 7.72890573822e-08, regulariztion_rates: 2.17687918751e-49, acc= 0.078
# learning_rate: 0.000813379195264, regulariztion_rates: 20291.174867, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.000255150657709, regulariztion_rates: 25.6922061368, acc= (0.4109591836734694, 0.41099999999999998)
# learning_rate: 1.57663381934e-05, regulariztion_rates: 0.000118341432259, acc= 0.087
# learning_rate: 0.000339634503207, regulariztion_rates: 3.90390686797e-15, acc= 0.087
# learning_rate: 0.000831156798947, regulariztion_rates: 0.000435011738703, acc= (0.49820408163265306, 0.48799999999999999)
# learning_rate: 0.00156719955658, regulariztion_rates: 4.04319903021e-45, acc= 0.538
# learning_rate: 1.2249777298e-06, regulariztion_rates: 2.85028815858e-09, acc= 0.078
# learning_rate: 0.000940655781332, regulariztion_rates: 1.72894754723e-21, acc= 0.554
# learning_rate: 0.000397728224679, regulariztion_rates: 6.29780572906e-06, acc= 0.113
# learning_rate: 0.0381339107801, regulariztion_rates: 7.19823649207e-31, acc= 0.466
# learning_rate: 0.220290859652, regulariztion_rates: 5.02700937142e-52, acc= 0.545
# learning_rate: 1.25409984911e-06, regulariztion_rates: 0.112851627825, acc= 0.081
# learning_rate: 0.00657698832111, regulariztion_rates: 6.18050044631e-25, acc= 0.551
# learning_rate: 0.00381815018843, regulariztion_rates: 4.34325671853e-36, acc= 0.517
# learning_rate: 4.65475540776e-06, regulariztion_rates: 7.4329858454e-05, acc= 0.08
# learning_rate: 0.000237476818489, regulariztion_rates: 9.91219671565e-55, acc= 0.524
# learning_rate: 1.52618302724e-05, regulariztion_rates: 7.78555201539e-05, acc= (0.41383673469387755, 0.42199999999999999)
# learning_rate: 3.03131152201e-05, regulariztion_rates: 1.26729809732e-45, acc= 0.517
# learning_rate: 1.16224878715e-06, regulariztion_rates: 1.15051334453e-22, acc= 0.384
# learning_rate: 9.51586009032e-06, regulariztion_rates: 0.0383153095716, acc= 0.106
# learning_rate: 0.000595983602728, regulariztion_rates: 299.978558759, acc= (0.38414285714285712, 0.38200000000000001)
# learning_rate: 7.81586222301e-05, regulariztion_rates: 0.0129360996034, acc= 0.079
# learning_rate: 4.98544038323e-06, regulariztion_rates: 0.0518796832601, acc= 0.114
# learning_rate: 0.00589029344792, regulariztion_rates: 6.16529327287e-41, acc= 0.078
# learning_rate: 9.56151320617e-05, regulariztion_rates: 21744.0216271, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.00298680599971, regulariztion_rates: 2.15514334813e-45, acc= 0.535
# learning_rate: 3.98872140653e-06, regulariztion_rates: 1.72450938037, acc= (0.38491836734693879, 0.379)
# learning_rate: 8.56581730982e-06, regulariztion_rates: 0.00433671102947, acc= (0.40130612244897962, 0.39500000000000002)
# learning_rate: 1.7619488187e-06, regulariztion_rates: 0.000878054437899, acc= (0.32824489795918366, 0.34300000000000003)
# learning_rate: 0.027991475699, regulariztion_rates: 1.85374463715e-57, acc= 0.461
# learning_rate: 8.03341285104e-07, regulariztion_rates: 0.00137177729838, acc= 0.113
# learning_rate: 2.19111034726e-06, regulariztion_rates: 1.28745336709e-05, acc= 0.083
# learning_rate: 1.8441284904e-06, regulariztion_rates: 0.000734594162237, acc= 0.083
# learning_rate: 0.000305988316697, regulariztion_rates: 0.0331949698281, acc= (0.4803265306122449, 0.46600000000000003)
# learning_rate: 0.0101067126021, regulariztion_rates: 2.18991129655e-29, acc= 0.49
# learning_rate: 4.09715750646e-06, regulariztion_rates: 7.35062792117e-50, acc= 0.49
# learning_rate: 0.000256529278327, regulariztion_rates: 1.07881663597e-25, acc= 0.078
# learning_rate: 0.0112210053778, regulariztion_rates: 3.35879527609e-43, acc= 0.112
# learning_rate: 1.57906241064e-06, regulariztion_rates: 2.07734578756e-48, acc= 0.078
# learning_rate: 0.000408118209318, regulariztion_rates: 9.4170232403e-22, acc= 0.078
# learning_rate: 0.0204766756996, regulariztion_rates: 1.61150660734e-39, acc= 0.392
# learning_rate: 0.00180905748998, regulariztion_rates: 7.08593334184e-38, acc= 0.552
# learning_rate: 0.000511231696543, regulariztion_rates: 71.3351207751, acc= (0.40548979591836737, 0.39100000000000001)
# learning_rate: 1.22756274565e-08, regulariztion_rates: 1.228431394e-26, acc= 0.078
# learning_rate: 9.69602571627e-06, regulariztion_rates: 0.0117226371786, acc= 0.08
# learning_rate: 0.00635710108508, regulariztion_rates: 1.55284645352e-43, acc= 0.588
# learning_rate: 1.93184687419e-05, regulariztion_rates: 2.87458728859e-12, acc= 0.112
# learning_rate: 1.20523024721e-06, regulariztion_rates: 0.00257086471592, acc= (0.27922448979591835, 0.28999999999999998)
# learning_rate: 0.000320035148141, regulariztion_rates: 2.28665922494e-26, acc= 0.462
# learning_rate: 2.00467224116e-05, regulariztion_rates: 1.12391551689e-05, acc= (0.41430612244897957, 0.41799999999999998)
# learning_rate: 1.06609193964e-06, regulariztion_rates: 10850.4694203, acc= (0.4136530612244898, 0.41099999999999998)
# learning_rate: 3.89217347606e-06, regulariztion_rates: 131.547398063, acc= (0.40904081632653061, 0.41199999999999998)
# learning_rate: 1.42798100751e-05, regulariztion_rates: 72519.8296306, acc= (0.085163265306122449, 0.075999999999999998)
# learning_rate: 1.3903346843e-06, regulariztion_rates: 1.02012585694e-07, acc= 0.078
# learning_rate: 1.66067203477e-05, regulariztion_rates: 6.80370515824e-05, acc= 0.081
# learning_rate: 1.60849816603e-10, regulariztion_rates: 3.31753125601e-24, acc= 0.078
# learning_rate: 0.000226922803147, regulariztion_rates: 2.8041424872e-34, acc= 0.078
# learning_rate: 1.57322194329e-06, regulariztion_rates: 1.02294259781e-49, acc= 0.078
# learning_rate: 1.42990550925e-06, regulariztion_rates: 87.2349890005, acc= (0.30985714285714283, 0.32800000000000001)
# learning_rate: 1.70918130021e-06, regulariztion_rates: 0.0658101315554, acc= 0.081
# learning_rate: 3.47807950594e-07, regulariztion_rates: 0.000697833479516, acc= 0.112
# learning_rate: 7.5125660256e-05, regulariztion_rates: 7.99875351978e-43, acc= 0.421
# learning_rate: 0.000574146431027, regulariztion_rates: 2.19529776228e-37, acc= 0.078
# learning_rate: 6.9096470791e-05, regulariztion_rates: 3.16146352664e-17, acc= 0.086
# learning_rate: 0.000604496177849, regulariztion_rates: 0.000105482241759, acc= (0.49373469387755103, 0.47599999999999998)
# learning_rate: 0.00366938433962, regulariztion_rates: 8.33807522765e-55, acc= 0.466
# learning_rate: 1.82541410331e-06, regulariztion_rates: 2.86091919555e-49, acc= 0.421
# learning_rate: 6.15820887833e-06, regulariztion_rates: 0.00783694209971, acc= (0.40075510204081632, 0.39700000000000002)
# learning_rate: 0.000431059895962, regulariztion_rates: 5.42746411853e-30, acc= 0.407
# learning_rate: 0.000894432427101, regulariztion_rates: 7.42917351953e-42, acc= 0.098
# learning_rate: 0.0122766158418, regulariztion_rates: 2.00261320152e-46, acc= 0.468
# learning_rate: 6.53365177896e-10, regulariztion_rates: 4.23028596981e-10, acc= 0.078
# learning_rate: 0.00528358294081, regulariztion_rates: 2.73087246002e-22, acc= 0.489
# learning_rate: 1.59795913548e-06, regulariztion_rates: 0.261517254635, acc= 0.111
# learning_rate: 3.66795070627e-07, regulariztion_rates: 0.0355397038845, acc= 0.082
# learning_rate: 5.64333385296e-06, regulariztion_rates: 2.96665590185e-14, acc= 0.274
# learning_rate: 2.48816453941e-08, regulariztion_rates: 2.86410100643e-08, acc= 0.078
# learning_rate: 0.000407368763575, regulariztion_rates: 36.5164327417, acc= (0.41169387755102038, 0.42599999999999999)
# learning_rate: 2.49298325982e-10, regulariztion_rates: 7.81001548541e-11, acc= 0.078
# learning_rate: 4.52575563091e-06, regulariztion_rates: 0.880431335311, acc= (0.38718367346938776, 0.36799999999999999)
# learning_rate: 2.28737727588e-05, regulariztion_rates: 4.98167237869e-19, acc= 0.078
# learning_rate: 0.000308587810825, regulariztion_rates: 3.42791841765, acc= (0.45991836734693875, 0.45700000000000002)
# learning_rate: 0.0225116854465, regulariztion_rates: 3.0613089714e-07, acc= 0.53
# learning_rate: 0.130065288145, regulariztion_rates: 1.00796606436e-57, acc= 0.594
# learning_rate: 5.7901221788e-06, regulariztion_rates: 8.10373175825e-27, acc= 0.107
# learning_rate: 0.00021432949414, regulariztion_rates: 2.9899177924e-46, acc= 0.514
# learning_rate: 4.82151519741e-05, regulariztion_rates: 0.000249443654738, acc= (0.43079591836734693, 0.438)
# learning_rate: 2.7648655327e-06, regulariztion_rates: 31.1200649318, acc= (0.37144897959183676, 0.378)
# learning_rate: 0.000176166955135, regulariztion_rates: 0.0253875289081, acc= 0.078
# learning_rate: 1.912268297e-06, regulariztion_rates: 1.10494267947e-46, acc= 0.078
# learning_rate: 0.0148873030121, regulariztion_rates: 7.66547616258e-24, acc= 0.464
# learning_rate: 8.42199072523e-06, regulariztion_rates: 0.88697347471, acc= 0.095
# learning_rate: 0.0879953555548, regulariztion_rates: 6.65045756865e-35, acc= 0.466
# learning_rate: 2.67273262111e-05, regulariztion_rates: 4.20674640312e-39, acc= 0.516
# learning_rate: 0.092423201579, regulariztion_rates: 2.28121795456e-35, acc= 0.508
# learning_rate: 0.000118409419599, regulariztion_rates: 4.83067100284e-32, acc= 0.078
# learning_rate: 0.000304845839507, regulariztion_rates: 0.0806325576137, acc= (0.47975510204081634, 0.46800000000000003)
# learning_rate: 0.00872714473591, regulariztion_rates: 1.73173067494e-45, acc= 0.303
# learning_rate: 0.0509577331783, regulariztion_rates: 6.87845323605e-57, acc= 0.556
# learning_rate: 1.31289303362e-06, regulariztion_rates: 0.00428752082911, acc= (0.30910204081632653, 0.30499999999999999)
# learning_rate: 0.0208205829301, regulariztion_rates: 8.11150479865e-55, acc= 0.576
# learning_rate: 1.43101365677e-06, regulariztion_rates: 0.000333259181143, acc= 0.086
# learning_rate: 8.04590678535e-07, regulariztion_rates: 0.00229201516584, acc= 0.104
# learning_rate: 1.26206085794e-09, regulariztion_rates: 8.23710550712e-18, acc= 0.078
# learning_rate: 0.0256337866619, regulariztion_rates: 3.87024127129e-35, acc= 0.554
# learning_rate: 0.000687196757693, regulariztion_rates: 4.92208618988, acc= (0.44900000000000001, 0.45100000000000001)
# learning_rate: 0.0979599510367, regulariztion_rates: 3.61210527109e-56, acc= 0.588
# learning_rate: 0.027837772294, regulariztion_rates: 2.24735268629e-31, acc= 0.498
# learning_rate: 3.82767961278e-06, regulariztion_rates: 1.05216853687e-44, acc= 0.078
# learning_rate: 2.00362672528e-05, regulariztion_rates: 6.01376710962, acc= 0.079
# learning_rate: 8.81433941199e-08, regulariztion_rates: 5.37279448666e-26, acc= 0.078
# learning_rate: 6.33789119426e-06, regulariztion_rates: 3.4759686687e-24, acc= 0.078
# learning_rate: 0.017609612654, regulariztion_rates: 3.27959833714e-12, acc= 0.107
# learning_rate: 0.000635320367249, regulariztion_rates: 4.60685546328e-33, acc= 0.538
# learning_rate: 1.31524804929e-08, regulariztion_rates: 1.55455181331e-35, acc= 0.078
# learning_rate: 4.9511051249e-07, regulariztion_rates: 0.000170658216627, acc= 0.08
# learning_rate: 4.78027794851e-10, regulariztion_rates: 3.53328689671e-10, acc= 0.078
# learning_rate: 0.000824645115994, regulariztion_rates: 58732.484393, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.000669834653213, regulariztion_rates: 74.669946696, acc= (0.40857142857142859, 0.42199999999999999)
# learning_rate: 0.000298675728507, regulariztion_rates: 7.34880084354e-43, acc= 0.332
# learning_rate: 0.0202386676852, regulariztion_rates: 8.23814534123e-16, acc= 0.496
# learning_rate: 9.38508914258e-07, regulariztion_rates: 1.739951765e-25, acc= 0.078
# learning_rate: 0.0010180477016, regulariztion_rates: 5.25317035785e-25, acc= 0.222
# learning_rate: 1.29524725748e-06, regulariztion_rates: 0.0604383237536, acc= (0.28012244897959182, 0.26100000000000001)
# learning_rate: 9.95486577377e-05, regulariztion_rates: 1.38148752644, acc= (0.44908163265306122, 0.44500000000000001)
# learning_rate: 1.00126087127e-05, regulariztion_rates: 0.00759330715858, acc= 0.079
# learning_rate: 0.000591234454362, regulariztion_rates: 19605.4760028, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.0150501234389, regulariztion_rates: 1.2500991125e-44, acc= 0.333
# learning_rate: 3.45700471047e-05, regulariztion_rates: 0.00110131225445, acc= (0.42210204081632652, 0.42399999999999999)
# learning_rate: 1.23484734536e-06, regulariztion_rates: 252.846339363, acc= (0.33334693877551019, 0.34200000000000003)
# learning_rate: 2.08407714254e-06, regulariztion_rates: 0.380671375879, acc= 0.083
# learning_rate: 4.16439717281e-06, regulariztion_rates: 0.0185870398189, acc= 0.078
# learning_rate: 0.00923129166853, regulariztion_rates: 4.97063897354e+13, acc= 0.087
# learning_rate: 0.000316503682786, regulariztion_rates: 2.16350761822e-30, acc= 0.517
# learning_rate: 7.60874552619e-07, regulariztion_rates: 1.32473871711e-18, acc= 0.078
# learning_rate: 0.00158703977146, regulariztion_rates: 4.47482202651e-16, acc= 0.415
# learning_rate: 1.65732001508e-05, regulariztion_rates: 1.75635011675e-42, acc= 0.404
# learning_rate: 8.44153643334e-06, regulariztion_rates: 0.00791680195367, acc= 0.082
# learning_rate: 0.000125434401737, regulariztion_rates: 1.1647509869e-32, acc= 0.515
# learning_rate: 0.00103858938448, regulariztion_rates: 5.82900772593e-23, acc= 0.49
# learning_rate: 1.92910858907e-07, regulariztion_rates: 0.00408781997477, acc= 0.098
# learning_rate: 0.0008166307472, regulariztion_rates: 1.1948234389e-23, acc= 0.514
# learning_rate: 5.92823498827e-05, regulariztion_rates: 1.79743451513e-22, acc= 0.086
# learning_rate: 6.91714562341e-05, regulariztion_rates: 2.35437962742e-29, acc= 0.409
# learning_rate: 1.72222613991e-07, regulariztion_rates: 0.000771137093872, acc= 0.079
# learning_rate: 0.0111253290595, regulariztion_rates: 4.73189590182e-22, acc= 0.398
# learning_rate: 0.00171972289226, regulariztion_rates: 1.41077965237e-43, acc= 0.556
# learning_rate: 1.6573988566e-06, regulariztion_rates: 0.265486564235, acc= (0.31461224489795919, 0.33300000000000002)
# learning_rate: 1.03852406696e-05, regulariztion_rates: 0.000251788672485, acc= (0.41087755102040818, 0.41399999999999998)
# learning_rate: 8.07486002051e-06, regulariztion_rates: 0.0255701109348, acc= (0.40102040816326529, 0.40500000000000003)
# learning_rate: 0.00873426913749, regulariztion_rates: 1.99812057233e-12, acc= 0.323
# learning_rate: 0.00500896012519, regulariztion_rates: 1.39864708456e-07, acc= 0.22
# learning_rate: 0.00072091551504, regulariztion_rates: 1.87579194184e-39, acc= 0.556
# learning_rate: 0.00663423769976, regulariztion_rates: 3.80575298732e-36, acc= 0.484
# learning_rate: 0.000486758475287, regulariztion_rates: 2.60210110375e-16, acc= 0.589
# learning_rate: 0.0215306089815, regulariztion_rates: 1.37139342447e-40, acc= 0.362
# learning_rate: 0.0015439190494, regulariztion_rates: 1.53988662474e-24, acc= 0.539
# learning_rate: 3.27308179255e-05, regulariztion_rates: 1.41708642878e-47, acc= 0.078
# learning_rate: 2.11048333969e-05, regulariztion_rates: 1.92185875685e-19, acc= 0.518
# learning_rate: 0.000156796758039, regulariztion_rates: 3.03785099259, acc= (0.45520408163265308, 0.44900000000000001)
# learning_rate: 9.08951021238e-05, regulariztion_rates: 2.10640959213e-32, acc= 0.37
# learning_rate: 5.90289733465e-05, regulariztion_rates: 3355.73477443, acc= (0.36720408163265306, 0.35599999999999998)
# learning_rate: 0.00153265497019, regulariztion_rates: 4.63538131841e-50, acc= 0.408
# learning_rate: 1.84803823397e-05, regulariztion_rates: 1.39072106718e-12, acc= 0.274
# learning_rate: 0.0336813697241, regulariztion_rates: 0.0288777581208, acc= 0.512
# learning_rate: 2.21438642121e-06, regulariztion_rates: 0.0257464358676, acc= (0.32593877551020406, 0.34100000000000003)
# learning_rate: 1.80646482969e-06, regulariztion_rates: 1.82192484029, acc= (0.31185714285714283, 0.32000000000000001)
# learning_rate: 1.00124424507e-07, regulariztion_rates: 0.00110905229603, acc= 0.078
# learning_rate: 0.0216617084554, regulariztion_rates: 6.17316738068e-47, acc= 0.518
# learning_rate: 0.00530682094132, regulariztion_rates: 8.02706028111e-13, acc= 0.517
# learning_rate: 0.000222863496975, regulariztion_rates: 7.59548353537, acc= (0.43928571428571428, 0.434)
# learning_rate: 1.53169587345e-05, regulariztion_rates: 0.00214444736913, acc= (0.41093877551020408, 0.41599999999999998)
# learning_rate: 0.000349083614086, regulariztion_rates: 8.30197056929e-11, acc= 0.384
# learning_rate: 0.0378123334049, regulariztion_rates: 7.79371026422e-12, acc= 0.528
# learning_rate: 2.39190743533e-06, regulariztion_rates: 76160.7842418, acc= (0.377, 0.38300000000000001)
# learning_rate: 2.18133653278e-06, regulariztion_rates: 0.05064323399, acc= (0.32816326530612244, 0.34300000000000003)
# learning_rate: 0.000123076752767, regulariztion_rates: 4.17209435423, acc= (0.44744897959183672, 0.44)
# learning_rate: 0.000558796921594, regulariztion_rates: 1.42918151991e-17, acc= 0.078
# learning_rate: 4.20476020668e-06, regulariztion_rates: 0.0167234896113, acc= 0.094
# learning_rate: 1.40133897912e-06, regulariztion_rates: 0.238712989105, acc= (0.29755102040816328, 0.29599999999999999)
# learning_rate: 0.00321044139718, regulariztion_rates: 6.06118900089e-22, acc= 0.312
# learning_rate: 0.0291212098672, regulariztion_rates: 3.30534462679e-39, acc= 0.078
# learning_rate: 9.14031349135e-06, regulariztion_rates: 0.000788698173265, acc= (0.40730612244897957, 0.40300000000000002)
# learning_rate: 2.82490532775e-05, regulariztion_rates: 2848.96961954, acc= (0.4056530612244898, 0.41599999999999998)
# learning_rate: 3.45166791786e-05, regulariztion_rates: 26.1991863609, acc= (0.41634693877551021, 0.42299999999999999)
# learning_rate: 1.97690017372e-06, regulariztion_rates: 1.97515044413e-05, acc= 0.078
# learning_rate: 0.000518566952706, regulariztion_rates: 3.4083989612e-49, acc= 0.467
# learning_rate: 1.65007820648e-06, regulariztion_rates: 0.419361107004, acc= (0.29351020408163264, 0.30399999999999999)
# learning_rate: 0.00221891037452, regulariztion_rates: 8.07729568925e-49, acc= 0.299
# learning_rate: 1.05169624702e-09, regulariztion_rates: 0.0487404890169, acc= 0.078
# learning_rate: 0.000222501138544, regulariztion_rates: 5.94334970545e-50, acc= 0.471
# learning_rate: 0.00287178995323, regulariztion_rates: 9.94568497002e-29, acc= 0.489
# learning_rate: 0.0099733985221, regulariztion_rates: 0.00825877634416, acc= 0.416
# learning_rate: 3.14850838194e-05, regulariztion_rates: 5.18986931425e-35, acc= 0.08
# learning_rate: 0.000615525441786, regulariztion_rates: 7.3326962894e-37, acc= 0.523
# learning_rate: 0.000285203967397, regulariztion_rates: 0.092041376178, acc= (0.47859183673469385, 0.47399999999999998)
# learning_rate: 0.000557279530668, regulariztion_rates: 42935.0952873, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.173820178096, regulariztion_rates: 1.36354618771e-49, acc= 0.442
# learning_rate: 1.36697770093e-05, regulariztion_rates: 1675.86205721, acc= (0.40730612244897957, 0.40699999999999997)
# learning_rate: 0.00203855317957, regulariztion_rates: 2.94018669554e-14, acc= 0.404
# learning_rate: 0.000205551877981, regulariztion_rates: 1.29637257948e-59, acc= 0.585
# learning_rate: 7.04331246016e-06, regulariztion_rates: 0.280867027279, acc= (0.40171428571428569, 0.40300000000000002)
# learning_rate: 2.67637115775e-06, regulariztion_rates: 17.7044153608, acc= 0.079
# learning_rate: 0.000290829255895, regulariztion_rates: 873.989410418, acc= (0.36075510204081634, 0.35399999999999998)
# learning_rate: 4.4808889337e-05, regulariztion_rates: 4.22323880681e-28, acc= 0.078
# learning_rate: 0.00328778795051, regulariztion_rates: 8.00972756388e-13, acc= 0.555
# learning_rate: 4.09535999129e-09, regulariztion_rates: 1.0638829993e-50, acc= 0.078
# learning_rate: 1.2503278544e-07, regulariztion_rates: 0.891931293751, acc= 0.08
# learning_rate: 0.000599269974953, regulariztion_rates: 0.0268474711098, acc= 0.078
# learning_rate: 5.32122366419e-05, regulariztion_rates: 89.8865742297, acc= (0.41412244897959183, 0.41799999999999998)
# learning_rate: 0.000431201926275, regulariztion_rates: 9.33893616186e-12, acc= 0.527
# learning_rate: 0.000620304260679, regulariztion_rates: 3.64925965023e-13, acc= 0.078
# learning_rate: 2.79346681635e-06, regulariztion_rates: 0.922793428662, acc= (0.37618367346938775, 0.38)
# learning_rate: 4.0087053903e-07, regulariztion_rates: 8.55929412168e-23, acc= 0.078
# learning_rate: 1.43354438628e-07, regulariztion_rates: 4.39165782899e-23, acc= 0.078
# learning_rate: 0.000326681764459, regulariztion_rates: 7.74478384714e-06, acc= 0.488
# learning_rate: 3.143959891e-05, regulariztion_rates: 0.00206783522412, acc= (0.420265306122449, 0.42499999999999999)
# learning_rate: 1.86649227175e-06, regulariztion_rates: 3.75245470594e-24, acc= 0.201
# learning_rate: 1.51878489504e-05, regulariztion_rates: 0.00375492953122, acc= (0.41351020408163264, 0.41599999999999998)
# learning_rate: 0.00857683348059, regulariztion_rates: 1.50726776821e-15, acc= 0.469
# learning_rate: 0.0394045139837, regulariztion_rates: 9.085019233e-24, acc= 0.445
# learning_rate: 0.00264695425421, regulariztion_rates: 4.76569561948e-42, acc= 0.519
# learning_rate: 3.60159048019e-09, regulariztion_rates: 1.28443725011e-41, acc= 0.078
# learning_rate: 0.000621872649923, regulariztion_rates: 0.00104946073858, acc= (0.49408163265306121, 0.48299999999999998)
# learning_rate: 1.3581896342e-06, regulariztion_rates: 1.67075832222, acc= (0.28046938775510205, 0.26900000000000002)
# learning_rate: 7.56086837159e-06, regulariztion_rates: 2.41229789825e-49, acc= 0.107
# learning_rate: 0.0015978038091, regulariztion_rates: 9.78903302339e-38, acc= 0.517
# learning_rate: 4.96927761928e-05, regulariztion_rates: 7.18227249123e-41, acc= 0.274
# learning_rate: 1.87899150726e-06, regulariztion_rates: 0.19973830837, acc= 0.081
# learning_rate: 0.0264507356231, regulariztion_rates: 2.23609837681e-21, acc= 0.515
# learning_rate: 2.01189394002e-09, regulariztion_rates: 3.21683638043e-28, acc= 0.078
# learning_rate: 0.0607792914899, regulariztion_rates: 3.31480477755e-12, acc= 0.201
# learning_rate: 2.00815459848e-06, regulariztion_rates: 0.0289511388733, acc= 0.082
# learning_rate: 3.72232195841e-09, regulariztion_rates: 3.24088526236e-28, acc= 0.078
# learning_rate: 0.056849590666, regulariztion_rates: 1.63409357359e-49, acc= 0.491
# learning_rate: 1.06670699142e-06, regulariztion_rates: 9.41893769067e-27, acc= 0.398
# learning_rate: 1.8506759204e-06, regulariztion_rates: 9008.99897562, acc= (0.40932653061224489, 0.40799999999999997)
# learning_rate: 7.77929572961e-06, regulariztion_rates: 3.59346576631e-37, acc= 0.404
# learning_rate: 4.97966513788e-06, regulariztion_rates: 1.17463996847e-05, acc= 0.082
# learning_rate: 0.000125838514064, regulariztion_rates: 4.28623486901e-45, acc= 0.078
# learning_rate: 7.79475947149e-05, regulariztion_rates: 8.72071061178e-12, acc= 0.2
# learning_rate: 0.017041106852, regulariztion_rates: 2.07039984004e-36, acc= 0.205
# learning_rate: 0.00324115850415, regulariztion_rates: 1.70160740036e-35, acc= 0.553
# learning_rate: 6.41456309043e-06, regulariztion_rates: 2.77027130546, acc= (0.4063469387755102, 0.40600000000000003)
# learning_rate: 0.0225008036098, regulariztion_rates: 5.16407323172e-15, acc= 0.564
# learning_rate: 0.00374126993385, regulariztion_rates: 4.04917778592e-33, acc= 0.482
# learning_rate: 2.8001129855e-06, regulariztion_rates: 0.00176631458108, acc= 0.131
# learning_rate: 0.000995660030499, regulariztion_rates: 8.99356917411e-42, acc= 0.468
# learning_rate: 3.48867122935e-06, regulariztion_rates: 2.78019957562e-29, acc= 0.274
# learning_rate: 9.54738866907e-06, regulariztion_rates: 0.321354528748, acc= 0.079
# learning_rate: 0.0528594234993, regulariztion_rates: 3.16484573492e-50, acc= 0.557
# learning_rate: 0.000833536102647, regulariztion_rates: 3.53914003415e-40, acc= 0.298
# learning_rate: 0.00113913888474, regulariztion_rates: 1.66070481783e-23, acc= 0.517
# learning_rate: 9.2084489844e-05, regulariztion_rates: 1.38448797409e-05, acc= 0.119
# learning_rate: 3.00163949975e-06, regulariztion_rates: 0.00466306885328, acc= 0.092
# learning_rate: 0.000522523886689, regulariztion_rates: 5.15654066363e-60, acc= 0.587
# learning_rate: 0.00455614806723, regulariztion_rates: 8.91583961164e-31, acc= 0.393
# learning_rate: 1.5534916177e-09, regulariztion_rates: 3.37560522712e-24, acc= 0.078
# learning_rate: 0.0336758665859, regulariztion_rates: 7.58010505316e-28, acc= 0.531
# learning_rate: 1.05247801793e-06, regulariztion_rates: 1.9275813018e-05, acc= 0.099
# learning_rate: 0.000180543552843, regulariztion_rates: 6.15098189704e-43, acc= 0.297
# learning_rate: 3.49970506233e-07, regulariztion_rates: 0.808683724754, acc= 0.097
# learning_rate: 0.000562592961852, regulariztion_rates: 168.085718818, acc= (0.39848979591836736, 0.38800000000000001)
# learning_rate: 8.07328773742e-06, regulariztion_rates: 5.11325631404e-05, acc= 0.08
# learning_rate: 0.00428876083922, regulariztion_rates: 2.58771725799e-28, acc= 0.495
# learning_rate: 0.00742135345991, regulariztion_rates: 1.15831447053e-46, acc= 0.49
# learning_rate: 6.76452198278e-05, regulariztion_rates: 9030.95760444, acc= (0.31995918367346937, 0.32600000000000001)
# learning_rate: 0.070535575785, regulariztion_rates: 4.55495131735e-10, acc= 0.536
# learning_rate: 1.41386863504e-06, regulariztion_rates: 0.000157053704208, acc= (0.27977551020408165, 0.25600000000000001)
# learning_rate: 4.76271016196e-05, regulariztion_rates: 1.79590327202e-11, acc= 0.208
# learning_rate: 0.00261570406927, regulariztion_rates: 5.6429101318e-18, acc= 0.513
# learning_rate: 2.8738881981e-05, regulariztion_rates: 1.58159944301e-44, acc= 0.517
# learning_rate: 0.0233441228334, regulariztion_rates: 9.4886893742e-39, acc= 0.43
# learning_rate: 0.00037572633222, regulariztion_rates: 1.13897008748e-28, acc= 0.482
# learning_rate: 0.000106635151628, regulariztion_rates: 4.23850903642e-25, acc= 0.515
# learning_rate: 4.83516580441e-06, regulariztion_rates: 0.0476210720136, acc= (0.39244897959183672, 0.39000000000000001)
# learning_rate: 0.000188653193168, regulariztion_rates: 1.15350910963e-06, acc= 0.191
# learning_rate: 0.0453042418178, regulariztion_rates: 1.33394152488e-32, acc= 0.416
# learning_rate: 0.00043497280483, regulariztion_rates: 0.043550574541, acc= 0.492
# learning_rate: 3.77514279314e-06, regulariztion_rates: 8579.29896946, acc= 0.079
# learning_rate: 4.45830421675e-05, regulariztion_rates: 0.000828497589477, acc= (0.42812244897959184, 0.42099999999999999)
# learning_rate: 0.0294133155752, regulariztion_rates: 1.46018181379e-23, acc= 0.21
# learning_rate: 0.000176709633843, regulariztion_rates: 4.56922884723e-30, acc= 0.515
# learning_rate: 7.07434089488e-06, regulariztion_rates: 10.3832185387, acc= (0.39826530612244898, 0.38300000000000001)
# learning_rate: 0.00536877792212, regulariztion_rates: 4.15199038145e-20, acc= 0.489
# learning_rate: 0.00473463808024, regulariztion_rates: 2.53534370235e-33, acc= 0.539
# learning_rate: 1.48420343344e-07, regulariztion_rates: 6.59433447511e-20, acc= 0.078
# learning_rate: 0.000459345962491, regulariztion_rates: 0.000141826962164, acc= (0.48855102040816328, 0.47299999999999998)
# learning_rate: 0.0548103031701, regulariztion_rates: 6.26283929447e-33, acc= 0.549
# learning_rate: 0.0003810282901, regulariztion_rates: 9.56899957374e-49, acc= 0.486
# learning_rate: 3.73601493747e-06, regulariztion_rates: 2.99075272871e-25, acc= 0.078
# learning_rate: 0.216996866089, regulariztion_rates: 2.54237828743e-09, acc= 0.589
# learning_rate: 0.00203684775885, regulariztion_rates: 9.29439158402e-34, acc= 0.536
# learning_rate: 0.000100465341488, regulariztion_rates: 4.61044530671e+41, acc= 0.087
# learning_rate: 0.000603392004031, regulariztion_rates: 9.78372773553e-18, acc= 0.078
# learning_rate: 0.000299146954234, regulariztion_rates: 18833.5798718, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.0632647381025, regulariztion_rates: 1.39693943585e-48, acc= 0.519
# learning_rate: 0.000544923544086, regulariztion_rates: 4.44870075515e-30, acc= 0.213
# learning_rate: 0.000284768327055, regulariztion_rates: 3.54002443961e-35, acc= 0.221
# learning_rate: 0.00135491079071, regulariztion_rates: 2.6547111763e-47, acc= 0.535
# learning_rate: 0.000336736684588, regulariztion_rates: 3.71190799133e-08, acc= 0.087
# learning_rate: 2.82383256089e-06, regulariztion_rates: 0.000899430445813, acc= (0.36222448979591837, 0.38)
# learning_rate: 9.21838758806e-05, regulariztion_rates: 5.08914431273e-05, acc= 0.078
# learning_rate: 0.0063409515585, regulariztion_rates: 2.79153468938e-20, acc= 0.479
# learning_rate: 5.1728939014e-06, regulariztion_rates: 249.688248941, acc= (0.41408163265306125, 0.41599999999999998)
# learning_rate: 4.03483794996e-06, regulariztion_rates: 2.70766785368e-05, acc= 0.097
# learning_rate: 0.000745291767094, regulariztion_rates: 7.25118286872e-45, acc= 0.432
# learning_rate: 0.000210925325642, regulariztion_rates: 70233.9092719, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.0279113525728, regulariztion_rates: 0.000974520787037, acc= 0.208
# learning_rate: 1.41330184832e-05, regulariztion_rates: 2.17096820235e-11, acc= 0.098
# learning_rate: 4.1371863226e-06, regulariztion_rates: 0.000171707691496, acc= (0.39024489795918366, 0.40899999999999997)
# learning_rate: 0.0148113151637, regulariztion_rates: 1.29165400817e-15, acc= 0.522
# learning_rate: 1.0763388369e-07, regulariztion_rates: 0.806030839443, acc= 0.079
# learning_rate: 0.0181604382572, regulariztion_rates: 9.38015784954e-47, acc= 0.409
# learning_rate: 0.000325765136006, regulariztion_rates: 0.0192028386405, acc= (0.48130612244897958, 0.47399999999999998)
# learning_rate: 2.1919696183e-09, regulariztion_rates: 2.42561182515e-34, acc= 0.078
# learning_rate: 1.94930390911e-05, regulariztion_rates: 7.8533697867e-31, acc= 0.481
# learning_rate: 0.0200979390014, regulariztion_rates: 4.60366619393e-34, acc= 0.58
# learning_rate: 0.0016540011035, regulariztion_rates: 2.36423090186e-45, acc= 0.3
# learning_rate: 3.05042431694e-06, regulariztion_rates: 1880.83173203, acc= 0.107
# learning_rate: 0.000164979850326, regulariztion_rates: 4.86571704176e-20, acc= 0.516
# learning_rate: 0.000871148481285, regulariztion_rates: 7.96424516744e-50, acc= 0.078
# learning_rate: 0.0320878096894, regulariztion_rates: 1.23169701036e-31, acc= 0.274
# learning_rate: 0.000199727468598, regulariztion_rates: 7.29020452029e-31, acc= 0.3
# learning_rate: 0.000127648969268, regulariztion_rates: 0.00692097527523, acc= (0.45718367346938776, 0.44900000000000001)
# learning_rate: 0.164489381045, regulariztion_rates: 4.21156234566e-26, acc= 0.189
# learning_rate: 1.84529959364e-06, regulariztion_rates: 1.29000701366e-05, acc= 0.081
# learning_rate: 3.31511164559e-09, regulariztion_rates: 2.9512235812e-29, acc= 0.078
# learning_rate: 0.000549077471219, regulariztion_rates: 34076.8460117, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.0130380440409, regulariztion_rates: 1.90034151584e-16, acc= 0.562
# learning_rate: 3.44248385348e-06, regulariztion_rates: 43852.1420868, acc= (0.39120408163265308, 0.39100000000000001)
# learning_rate: 2.39189651421e-06, regulariztion_rates: 0.000442525090537, acc= (0.34918367346938778, 0.35499999999999998)
# learning_rate: 1.8478802797e-06, regulariztion_rates: 1.15000729523e-28, acc= 0.078
# learning_rate: 1.35151346281e-05, regulariztion_rates: 4.81901520576e-38, acc= 0.274
# learning_rate: 0.000509023912018, regulariztion_rates: 0.0425857343008, acc= (0.49095918367346941, 0.47899999999999998)
# learning_rate: 0.0246413398695, regulariztion_rates: 4.29859768559e-37, acc= 0.478
# learning_rate: 3.99472789825e-05, regulariztion_rates: 0.00131915688272, acc= 0.087
# learning_rate: 0.0210313855621, regulariztion_rates: 7.58779360063e-39, acc= 0.527
# learning_rate: 1.25998901308e-06, regulariztion_rates: 5.00092105064e-05, acc= (0.294265306122449, 0.29299999999999998)
# learning_rate: 0.0166981952484, regulariztion_rates: 2.96024708349e-08, acc= 0.538
# learning_rate: 0.07523144134, regulariztion_rates: 9.48979280647e-46, acc= 0.492
# learning_rate: 0.000913990625166, regulariztion_rates: 2847.05726811, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 0.0416650274713, regulariztion_rates: 1.57040540922e-18, acc= 0.405
# learning_rate: 4.5568649063e-06, regulariztion_rates: 0.000116547082641, acc= 0.081
# learning_rate: 8.15802898896e-07, regulariztion_rates: 1.14063698379e-35, acc= 0.078
# learning_rate: 0.072486526311, regulariztion_rates: 1.23454020454e-11, acc= 0.509
# learning_rate: 2.08419817596e-06, regulariztion_rates: 4.83764527227e-09, acc= 0.078
# learning_rate: 0.000113085130027, regulariztion_rates: 4.07708905736e-37, acc= 0.466
# learning_rate: 1.81179736836e-06, regulariztion_rates: 3.1441787501e-20, acc= 0.078
# learning_rate: 0.00096102379235, regulariztion_rates: 4.83379930301e-05, acc= (0.50034693877551017, 0.48399999999999999)
# learning_rate: 0.00138565484031, regulariztion_rates: 2.1498681915e-22, acc= 0.553
# learning_rate: 2.77309269219e-05, regulariztion_rates: 53372.0601721, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 1.10301010085e-05, regulariztion_rates: 5.72943578002e-05, acc= 0.079
# learning_rate: 6.12051433974e-05, regulariztion_rates: 2.74241749851e-21, acc= 0.489
# learning_rate: 1.90029974278e-05, regulariztion_rates: 1.44789516777e-11, acc= 0.421
# learning_rate: 0.0451992195446, regulariztion_rates: 3.47269105204e-40, acc= 0.515
# learning_rate: 7.48372378199e-07, regulariztion_rates: 0.000106139626593, acc= 0.107
# learning_rate: 0.000759359966167, regulariztion_rates: 6.16470052015e-21, acc= 0.08
# learning_rate: 1.29723086493e-05, regulariztion_rates: 3.71864273746, acc= (0.40883673469387755, 0.40100000000000002)
# learning_rate: 6.06382304776e-10, regulariztion_rates: 1.32412622685e-07, acc= 0.078
# learning_rate: 5.25801088603e-07, regulariztion_rates: 3.17973037018e-05, acc= 0.081
# learning_rate: 4.71149277552e-05, regulariztion_rates: 0.00899388543224, acc= (0.42977551020408161, 0.42999999999999999)
# learning_rate: 0.000118904671137, regulariztion_rates: 1.20449760015e-51, acc= 0.461
# learning_rate: 2.82829656977e-07, regulariztion_rates: 0.000233792180243, acc= 0.11
# learning_rate: 0.00374907328643, regulariztion_rates: 6.19232055875e-20, acc= 0.58
# learning_rate: 4.50111014166e-06, regulariztion_rates: 0.0275024891936, acc= (0.39138775510204082, 0.38600000000000001)
# learning_rate: 9.87659780806e-07, regulariztion_rates: 5.06492942172e-44, acc= 0.078
# learning_rate: 5.70123637982e-06, regulariztion_rates: 0.000132307003984, acc= 0.094
# learning_rate: 0.0118146103267, regulariztion_rates: 1.07222934896e-59, acc= 0.575
# learning_rate: 0.0102785923076, regulariztion_rates: 9.98224479524e-17, acc= 0.47
# learning_rate: 3.62858295546e-05, regulariztion_rates: 11269.1367113, acc= 0.079
# learning_rate: 1.67264057631e-05, regulariztion_rates: 25256.274543, acc= (0.30848979591836734, 0.29799999999999999)
# learning_rate: 0.00206530756463, regulariztion_rates: 1.10012929232e-31, acc= 0.296
# learning_rate: 0.000157568841621, regulariztion_rates: 1.03061197579, acc= (0.4620408163265306, 0.45200000000000001)
# learning_rate: 4.93955153066e-06, regulariztion_rates: 3.79403506137e-31, acc= 0.107
# learning_rate: 7.52915058557e-06, regulariztion_rates: 0.273922433404, acc= (0.40269387755102043, 0.40899999999999997)
# learning_rate: 1.63579705807e-05, regulariztion_rates: 3.33222994226e-12, acc= 0.478
# learning_rate: 1.43341223662e-06, regulariztion_rates: 0.0393639321654, acc= (0.28479591836734691, 0.27700000000000002)
# learning_rate: 3.00115368155e-06, regulariztion_rates: 337.454976692, acc= (0.41453061224489796, 0.42099999999999999)
# learning_rate: 0.000463327191821, regulariztion_rates: 6.93431469118e-15, acc= 0.549
# learning_rate: 1.41563418067e-05, regulariztion_rates: 31424.7702972, acc= (0.33518367346938777, 0.32700000000000001)
# learning_rate: 1.49278833991e-05, regulariztion_rates: 14313.726555, acc= (0.38614285714285712, 0.36099999999999999)
# learning_rate: 1.02267337345e-05, regulariztion_rates: 0.00071673212901, acc= (0.40924489795918367, 0.42199999999999999)
# learning_rate: 9.84147613244e-08, regulariztion_rates: 1.29248546857e-46, acc= 0.078
# learning_rate: 0.000985042267043, regulariztion_rates: 8.24128768774e-11, acc= 0.488
# learning_rate: 1.87307217721e-06, regulariztion_rates: 726.358188265, acc= 0.107
# learning_rate: 0.047518438815, regulariztion_rates: 1.53313716976e-33, acc= 0.539
# learning_rate: 5.71111922098e-09, regulariztion_rates: 9.47082681482e-20, acc= 0.078
# learning_rate: 0.00825889576422, regulariztion_rates: 5.21176084746e-57, acc= 0.564
# learning_rate: 1.75848997487e-06, regulariztion_rates: 23776.2759007, acc= (0.41718367346938773, 0.42599999999999999)
# learning_rate: 0.000122863806698, regulariztion_rates: 3.32755234455e-35, acc= 0.3
# learning_rate: 7.85001410141e-07, regulariztion_rates: 0.00338645050036, acc= 0.081
# learning_rate: 1.72311657173e-06, regulariztion_rates: 3.37856815656e-18, acc= 0.078
# learning_rate: 0.00985046618238, regulariztion_rates: 1.12548124772e-28, acc= 0.6
# learning_rate: 1.37605079665e-08, regulariztion_rates: 1.17428514972e-12, acc= 0.078
# learning_rate: 2.54023482301e-06, regulariztion_rates: 0.123450502954, acc= (0.3560204081632653, 0.35099999999999998)
# learning_rate: 0.00286740771605, regulariztion_rates: 2.92496928433e-23, acc= 0.421
# learning_rate: 0.0159500511448, regulariztion_rates: 7.62169890948e-13, acc= 0.542
# learning_rate: 0.00431915451027, regulariztion_rates: 6.70584947993e-32, acc= 0.507
# learning_rate: 1.32462345485e-05, regulariztion_rates: 1.62932009505e-18, acc= 0.393
# learning_rate: 0.0304284266879, regulariztion_rates: 1.72889869152e-17, acc= 0.525
# learning_rate: 1.26015370094e-06, regulariztion_rates: 0.029590498294, acc= (0.28593877551020408, 0.28799999999999998)
# learning_rate: 0.0402280685581, regulariztion_rates: 4.04861203502e-28, acc= 0.483
# learning_rate: 4.0752385546e-06, regulariztion_rates: 1.97842740032e-28, acc= 0.107
# learning_rate: 1.19497732742e-07, regulariztion_rates: 0.000769145985833, acc= 0.083
# learning_rate: 1.80536395646e-07, regulariztion_rates: 4.1639496009e-05, acc= 0.083
# learning_rate: 0.00504015868617, regulariztion_rates: 5.60960346712e-34, acc= 0.229
# learning_rate: 3.02706387435e-06, regulariztion_rates: 0.844923476853, acc= (0.36502040816326531, 0.34999999999999998)
# learning_rate: 1.26102096687e-06, regulariztion_rates: 0.0389881636175, acc= 0.08
# learning_rate: 0.01600236245, regulariztion_rates: 2.01876496017e-26, acc= 0.486
# learning_rate: 0.000290164391727, regulariztion_rates: 689.292696523, acc= (0.35671428571428571, 0.35899999999999999)
# learning_rate: 0.000222320406617, regulariztion_rates: 0.697740173027, acc= (0.46924489795918367, 0.45900000000000002)
# learning_rate: 0.00155961428961, regulariztion_rates: 2.08821137106e-11, acc= 0.538
# learning_rate: 9.96874487668e-06, regulariztion_rates: 33013.6135376, acc= (0.34287755102040818, 0.35999999999999999)
# learning_rate: 5.05142522208e-05, regulariztion_rates: 6344.39851247, acc= (0.36867346938775508, 0.377)
# learning_rate: 0.000170761996086, regulariztion_rates: 289.57251678, acc= (0.40202040816326529, 0.40699999999999997)
# learning_rate: 5.42009891777e-05, regulariztion_rates: 3.90575681043e-19, acc= 0.078
# learning_rate: 1.14012268292e-06, regulariztion_rates: 0.0399800762625, acc= (0.25763265306122451, 0.246)
# learning_rate: 6.4361501943e-06, regulariztion_rates: 0.0123222430519, acc= 0.083
# learning_rate: 1.82021204779e-06, regulariztion_rates: 0.0264033212255, acc= (0.33040816326530614, 0.33900000000000002)
# learning_rate: 0.000220298385975, regulariztion_rates: 1.84451697689e-23, acc= 0.078
# ...
# learning_rate: 0.0149165775494, regulariztion_rates: 3.20213673093e-28, acc= 0.493
# learning_rate: 1.17678695534e-05, regulariztion_rates: 0.000430619245722, acc= 0.078
# learning_rate: 3.47496389506e-07, regulariztion_rates: 0.270773260039, acc= 0.098
# learning_rate: 0.000270249136109, regulariztion_rates: 4.10197808718, acc= (0.45530612244897961, 0.44800000000000001)
# learning_rate: 9.35439487908e-06, regulariztion_rates: 384.398836964, acc= (0.4137142857142857, 0.40400000000000003)
# learning_rate: 4.89687393131e-07, regulariztion_rates: 0.0176918626855, acc= 0.081
# learning_rate: 0.0573829067264, regulariztion_rates: 1.74000467312e-18, acc= 0.512
# learning_rate: 0.0913674406589, regulariztion_rates: 1.40811058241e-31, acc= 0.141
# learning_rate: 5.56862405932e-05, regulariztion_rates: 2.04136831081e-28, acc= 0.107
# learning_rate: 0.00118109135826, regulariztion_rates: 3.25430920419e-59, acc= 0.536
# learning_rate: 9.24583364313e-05, regulariztion_rates: 1.90914797697e-14, acc= 0.518
# learning_rate: 0.0155473449642, regulariztion_rates: 2.41133990735e-41, acc= 0.519
# learning_rate: 0.0467467951996, regulariztion_rates: 1.69815053264e-19, acc= 0.516
# learning_rate: 0.000368143021213, regulariztion_rates: 1.53866344325e-27, acc= 0.208
# learning_rate: 0.0144238013358, regulariztion_rates: 1.44131118951e-29, acc= 0.516
# learning_rate: 0.137846442763, regulariztion_rates: 4.48755185195e-07, acc= 0.517
# learning_rate: 0.0168969907374, regulariztion_rates: 2.99876139673e-37, acc= 0.481
# learning_rate: 0.000309724842833, regulariztion_rates: 0.00243622305096, acc= (0.47875510204081634, 0.46999999999999997)
# learning_rate: 1.0628438291e-06, regulariztion_rates: 1.72428984528e-42, acc= 0.078
# learning_rate: 0.000117662512132, regulariztion_rates: 2.46060091986e-48, acc= 0.297
# learning_rate: 0.000560075911639, regulariztion_rates: 0.0622136913997, acc= (0.49222448979591837, 0.47999999999999998)
# learning_rate: 0.000541519259682, regulariztion_rates: 7.51815788674e-37, acc= 0.107
# learning_rate: 5.66580727555e-06, regulariztion_rates: 2.40664798142, acc= (0.39271428571428574, 0.39300000000000002)
# learning_rate: 6.70717874144e-05, regulariztion_rates: 2841.66129592, acc= (0.39216326530612244, 0.41499999999999998)
# learning_rate: 4.70077728885e-06, regulariztion_rates: 1540.07386424, acc= 0.079
# learning_rate: 0.0837962386065, regulariztion_rates: 5.36418657511e-32, acc= 0.527
# learning_rate: 4.84650020573e-05, regulariztion_rates: 2.21572668628, acc= (0.42916326530612248, 0.42699999999999999)
# learning_rate: 5.21957050232e-07, regulariztion_rates: 1.23929526366e-16, acc= 0.078
# learning_rate: 0.000569167081601, regulariztion_rates: 3.0603449384e-13, acc= 0.587
# learning_rate: 0.00782512521782, regulariztion_rates: 3.71565872168e-50, acc= 0.487
# learning_rate: 0.0635283352589, regulariztion_rates: 3.55779813599e-15, acc= 0.587
# learning_rate: 0.000754357868865, regulariztion_rates: 2.48661963441e-23, acc= 0.471
# learning_rate: 3.13128573574e-06, regulariztion_rates: 3.59897964954e-05, acc= 0.078
# learning_rate: 1.76066116897e-06, regulariztion_rates: 1.20222516624e-36, acc= 0.208
# learning_rate: 0.000896848908261, regulariztion_rates: 9.47221853824e-10, acc= 0.558
# learning_rate: 0.00119457639256, regulariztion_rates: 7.06007884993e-35, acc= 0.514
# learning_rate: 3.59088575512e-06, regulariztion_rates: 0.0140198383056, acc= (0.38787755102040816, 0.38400000000000001)
# learning_rate: 0.0361760921703, regulariztion_rates: 2.90705734111e-07, acc= 0.482
# learning_rate: 3.80808659161e-06, regulariztion_rates: 1.09432917027e-43, acc= 0.496
# learning_rate: 2.24871056594e-06, regulariztion_rates: 14244.6909437, acc= 0.079
# learning_rate: 0.000295815642893, regulariztion_rates: 6170.01306714, acc= (0.10026530612244898, 0.086999999999999994)
# learning_rate: 8.86474911858e-05, regulariztion_rates: 0.0775931443862, acc= (0.44610204081632654, 0.441)
# learning_rate: 0.00110976709894, regulariztion_rates: 5.24001625838e-21, acc= 0.079
# learning_rate: 2.42554737192e-05, regulariztion_rates: 1.62824781537, acc= 0.079
# learning_rate: 2.96189603252e-06, regulariztion_rates: 3.92720986958e-19, acc= 0.333
# learning_rate: 1.05382527151e-05, regulariztion_rates: 4.10801650526e-27, acc= 0.107
# learning_rate: 0.000819427407702, regulariztion_rates: 652.902722658, acc= (0.30208163265306121, 0.29699999999999999)
# learning_rate: 0.000698685483126, regulariztion_rates: 0.00127916444858, acc= (0.49653061224489797, 0.48799999999999999)
# learning_rate: 0.000576440906886, regulariztion_rates: 0.375114717283, acc= (0.48899999999999999, 0.48099999999999998)
# learning_rate: 4.14236634925e-06, regulariztion_rates: 0.00155275770045, acc= (0.38522448979591839, 0.40300000000000002)
# learning_rate: 1.89791472743e-05, regulariztion_rates: 0.709693095701, acc= (0.41312244897959183, 0.41799999999999998)
# learning_rate: 9.12345256556e-05, regulariztion_rates: 0.653888345752, acc= (0.44791836734693879, 0.45000000000000001)
# learning_rate: 5.15771258166e-06, regulariztion_rates: 48.441824164, acc= 0.079
# learning_rate: 2.36680615285e-05, regulariztion_rates: 5.79596811923e-17, acc= 0.078
# learning_rate: 0.000252227179315, regulariztion_rates: 4.66175146827e-12, acc= 0.49
# learning_rate: 0.000463735352212, regulariztion_rates: 6.86776341758e-30, acc= 0.471
# learning_rate: 1.57277636519e-06, regulariztion_rates: 0.00075524293459, acc= 0.078
# learning_rate: 0.000250387372163, regulariztion_rates: 0.0305527284377, acc= 0.078
# learning_rate: 5.38550031178e-06, regulariztion_rates: 2.95463067255e-43, acc= 0.403
# learning_rate: 0.000479886314962, regulariztion_rates: 9.01015409322e-23, acc= 0.078
# learning_rate: 0.0172060327417, regulariztion_rates: 2.91849450125e-46, acc= 0.487
# learning_rate: 5.24035211677e-07, regulariztion_rates: 0.230214939004, acc= 0.082
# learning_rate: 0.0116197287858, regulariztion_rates: 6.30677197455e-28, acc= 0.433
# learning_rate: 0.00575955981678, regulariztion_rates: 1.35957096126e-14, acc= 0.516
# learning_rate: 1.86309663424e-06, regulariztion_rates: 0.40437162598, acc= (0.32279591836734695, 0.32400000000000001)
# learning_rate: 0.000160344598438, regulariztion_rates: 1.94036729213e-25, acc= 0.339
# learning_rate: 0.0864963088151, regulariztion_rates: 6.98351031608e-33, acc= 0.297
# learning_rate: 0.000220399764553, regulariztion_rates: 6.60360235729e-31, acc= 0.209
# learning_rate: 0.160430791317, regulariztion_rates: 2.2193805872e-31, acc= 0.559
# learning_rate: 0.0376176458115, regulariztion_rates: 5.59923933903e-34, acc= 0.107
# learning_rate: 3.49408382418e-10, regulariztion_rates: 0.000292426686419, acc= 0.078
# learning_rate: 0.00470771910869, regulariztion_rates: 1.62087196302e-35, acc= 0.465
# learning_rate: 1.18817813998e-05, regulariztion_rates: 3895.49875624, acc= (0.40728571428571431, 0.41499999999999998)
# learning_rate: 0.0157492550577, regulariztion_rates: 6.59816519156e-45, acc= 0.527
# learning_rate: 2.9638538831e-08, regulariztion_rates: 1.39660801603e-09, acc= 0.078
# learning_rate: 0.00207472650037, regulariztion_rates: 2.73328283999e-26, acc= 0.511
# learning_rate: 0.00407650330949, regulariztion_rates: 3.21323795487e-42, acc= 0.536
# learning_rate: 4.06687544288e-05, regulariztion_rates: 8.00177491199e-26, acc= 0.117
# learning_rate: 3.97978414293e-05, regulariztion_rates: 123.847693395, acc= (0.41259183673469385, 0.41399999999999998)
# learning_rate: 0.00182985977298, regulariztion_rates: 8.23136788553e-30, acc= 0.446
# learning_rate: 0.000131368205546, regulariztion_rates: 2.90862138545e-48, acc= 0.37
# learning_rate: 1.8021282468e-06, regulariztion_rates: 8097.06743164, acc= (0.40536734693877552, 0.40600000000000003)
# learning_rate: 0.0150726813751, regulariztion_rates: 8.64031128386e-47, acc= 0.383
# learning_rate: 1.60923040743e-07, regulariztion_rates: 1.89106678413e-05, acc= 0.078
# learning_rate: 2.44236255521e-05, regulariztion_rates: 1.94908489777e-40, acc= 0.512
# learning_rate: 0.00598592965229, regulariztion_rates: 8.97126943218e-37, acc= 0.52
# learning_rate: 0.000255896334005, regulariztion_rates: 2.31237915223e-18, acc= 0.079
# learning_rate: 0.000664225168702, regulariztion_rates: 6.45573671833e-40, acc= 0.518
# learning_rate: 6.99693905536e-06, regulariztion_rates: 5.06763553223e-33, acc= 0.466
# learning_rate: 0.00438680639447, regulariztion_rates: 3.58306741878e-28, acc= 0.497
# learning_rate: 4.11779956671e-06, regulariztion_rates: 1.80060672999e-40, acc= 0.37
# learning_rate: 1.51753526022e-06, regulariztion_rates: 0.49936400218, acc= (0.29655102040816328, 0.29199999999999998)
# learning_rate: 0.0124720032027, regulariztion_rates: 8.10886112482e-38, acc= 0.512
# learning_rate: 0.000291383987711, regulariztion_rates: 3.99290868947e-27, acc= 0.517
# learning_rate: 0.000124939861754, regulariztion_rates: 4.42690929765e-05, acc= (0.45683673469387753, 0.44800000000000001)
# learning_rate: 2.87376477415e-05, regulariztion_rates: 3.99821866124, acc= (0.41757142857142859, 0.42299999999999999)
# learning_rate: 1.01034450269e-06, regulariztion_rates: 4.9613485952e-43, acc= 0.107
# learning_rate: 2.45862942284e-05, regulariztion_rates: 1.8329617006e-46, acc= 0.489
# learning_rate: 0.000836217437025, regulariztion_rates: 0.473226394603, acc= (0.49030612244897959, 0.47899999999999998)
# learning_rate: 0.000483043455329, regulariztion_rates: 0.531005903257, acc= (0.48491836734693877, 0.47999999999999998)
# learning_rate: 7.34059730598e-05, regulariztion_rates: 0.0695933433306, acc= 0.078
# learning_rate: 4.60025291897e-05, regulariztion_rates: 2.82457851753e-42, acc= 0.229
# learning_rate: 0.000567431967372, regulariztion_rates: 2.48544491284e-58, acc= 0.591
# learning_rate: 2.89739913786e-05, regulariztion_rates: 77.1432463125, acc= (0.41412244897959183, 0.41899999999999998)
# learning_rate: 1.01011580738e-05, regulariztion_rates: 1.07823354405e-22, acc= 0.398
# learning_rate: 2.26032159461e-06, regulariztion_rates: 29983.4818984, acc= (0.4064081632653061, 0.40600000000000003)
# learning_rate: 8.07701647863e-06, regulariztion_rates: 9769.14730904, acc= 0.079
# learning_rate: 4.35307537726e-06, regulariztion_rates: 0.0714180259421, acc= 0.08
# learning_rate: 0.000193449396197, regulariztion_rates: 3.62020658601e-08, acc= 0.517
# learning_rate: 1.62600856796e-06, regulariztion_rates: 2.13188112826e-48, acc= 0.445
# learning_rate: 0.000450026004716, regulariztion_rates: 12.0078523755, acc= (0.42742857142857144, 0.42699999999999999)
# learning_rate: 0.0086123113447, regulariztion_rates: 2.2221563261e-18, acc= 0.486
# learning_rate: 3.29546625407e-05, regulariztion_rates: 1.38776893816e-06, acc= 0.078
# learning_rate: 0.00112841751707, regulariztion_rates: 2.12850636863e-47, acc= 0.482
# learning_rate: 1.27096916944e-09, regulariztion_rates: 7.22943125385e-13, acc= 0.078
# learning_rate: 0.0227523101957, regulariztion_rates: 1.06966062594e-20, acc= 0.54
# learning_rate: 0.04252654085, regulariztion_rates: 1.94087858861e-43, acc= 0.39
# learning_rate: 0.000233763863212, regulariztion_rates: 0.000272612359661, acc= (0.47420408163265304, 0.46600000000000003)
# learning_rate: 0.00665273759331, regulariztion_rates: 2.04556224981e-20, acc= 0.574
# learning_rate: 1.58078025038e-05, regulariztion_rates: 1.8171989274e-26, acc= 0.517
# learning_rate: 2.25105347138e-06, regulariztion_rates: 2.52161057302e-41, acc= 0.078
# learning_rate: 1.18703498351e-05, regulariztion_rates: 0.0031795528157, acc= 0.078
# learning_rate: 3.60719269463e-05, regulariztion_rates: 2.52847535203e-40, acc= 0.078
# learning_rate: 4.99743276213e-06, regulariztion_rates: 0.30298607939, acc= 0.079
# learning_rate: 7.31265389906e-06, regulariztion_rates: 0.000427843049964, acc= (0.40785714285714286, 0.41299999999999998)
# learning_rate: 0.000999374374211, regulariztion_rates: 8.87413209881e-31, acc= 0.597
# learning_rate: 7.62776288175e-05, regulariztion_rates: 1.75232266587e-23, acc= 0.078
# learning_rate: 8.87026683706e-05, regulariztion_rates: 4.69117155386e-05, acc= 0.107
# learning_rate: 0.177856455067, regulariztion_rates: 4.25512612131e-36, acc= 0.533
# learning_rate: 4.83547269308e-06, regulariztion_rates: 2.73676831338e-12, acc= 0.403
# learning_rate: 0.000183336936025, regulariztion_rates: 145.774400658, acc= (0.41218367346938778, 0.40999999999999998)
# learning_rate: 1.04962320852e-05, regulariztion_rates: 7.32138057153e-05, acc= (0.41304081632653061, 0.40899999999999997)
# learning_rate: 0.0330068967583, regulariztion_rates: 9.91602874434e-48, acc= 0.359
# learning_rate: 1.29313462328e-06, regulariztion_rates: 0.00209297560571, acc= (0.28191836734693876, 0.29099999999999998)
# learning_rate: 9.56871886201e-06, regulariztion_rates: 33603.8423002, acc= (0.34804081632653061, 0.34999999999999998)
# learning_rate: 0.0881485879522, regulariztion_rates: 5.72879860798e-48, acc= 0.293
# learning_rate: 2.3115472698e-05, regulariztion_rates: 2.52534819358e-12, acc= 0.517
# learning_rate: 0.0293679269936, regulariztion_rates: 2.46366035231e-31, acc= 0.442
# learning_rate: 0.00018057396662, regulariztion_rates: 0.000406604232155, acc= (0.46816326530612246, 0.45800000000000002)
# learning_rate: 0.000104561422887, regulariztion_rates: 154.703275129, acc= (0.41248979591836737, 0.41999999999999998)
# learning_rate: 4.97087391993e-06, regulariztion_rates: 5564.78963592, acc= (0.41273469387755102, 0.43099999999999999)
# learning_rate: 0.000256097821991, regulariztion_rates: 3.16481412345e-24, acc= 0.079
# learning_rate: 1.25376707191e-05, regulariztion_rates: 1.85933039539e-16, acc= 0.078
# learning_rate: 5.62662335505e-05, regulariztion_rates: 0.00331258217185, acc= (0.43467346938775508, 0.433)
# learning_rate: 0.00112904552236, regulariztion_rates: 2.71389022521e-38, acc= 0.221
# learning_rate: 0.000878032113991, regulariztion_rates: 124.422554202, acc= (0.39753061224489794, 0.39100000000000001)
# learning_rate: 0.0957249923949, regulariztion_rates: 1.08778382039e-43, acc= 0.538
# learning_rate: 2.08565613733e-06, regulariztion_rates: 4.86101673027e-05, acc= (0.33434693877551019, 0.29899999999999999)
# learning_rate: 0.00550221056963, regulariztion_rates: 2.87091044197e-15, acc= 0.536
# learning_rate: 2.34656145832e-06, regulariztion_rates: 3.57188149129e-05, acc= 0.079
# learning_rate: 0.000126831365562, regulariztion_rates: 2.53609354307e-41, acc= 0.553
# learning_rate: 0.00195405678318, regulariztion_rates: 1.98389936764e-45, acc= 0.51
# learning_rate: 0.00194803743451, regulariztion_rates: 2.59437331836e-16, acc= 0.406
# learning_rate: 1.87012923979e-05, regulariztion_rates: 8.14430192576e-45, acc= 0.079
# learning_rate: 0.0059919861136, regulariztion_rates: 1.0155072552e-54, acc= 0.555
# learning_rate: 0.015571619808, regulariztion_rates: 2.64292607257e-37, acc= 0.403
# learning_rate: 0.0453011526945, regulariztion_rates: 5.18971466032e-40, acc= 0.491
# learning_rate: 9.18339865688e-08, regulariztion_rates: 2.08266000318e-46, acc= 0.078
# learning_rate: 0.0166373519777, regulariztion_rates: 2.53229272891e-48, acc= 0.473
# learning_rate: 6.93711853194e-06, regulariztion_rates: 0.0167346438639, acc= 0.107
# learning_rate: 0.000238859811296, regulariztion_rates: 6.34979599468e-06, acc= 0.485
# learning_rate: 1.69125835196e-06, regulariztion_rates: 22924.9133641, acc= (0.4089591836734694, 0.39700000000000002)
# learning_rate: 0.000130569113705, regulariztion_rates: 3.4345177429e-31, acc= 0.517
# learning_rate: 0.0200742755872, regulariztion_rates: 3.66724106135e-10, acc= 0.514
# learning_rate: 0.000820517178639, regulariztion_rates: 5.21623448159e-06, acc= 0.519
# learning_rate: 0.0954000594788, regulariztion_rates: 6.32577293934e-32, acc= 0.524
# learning_rate: 6.69783355118e-06, regulariztion_rates: 2.26271711986e-12, acc= 0.082
# learning_rate: 2.50760815054e-07, regulariztion_rates: 3.2131879988e-05, acc= 0.113
# learning_rate: 0.000661294769098, regulariztion_rates: 6.59471777881e-47, acc= 0.078
# learning_rate: 7.00762129138e-06, regulariztion_rates: 0.000122412739658, acc= (0.40100000000000002, 0.38900000000000001)
# learning_rate: 0.00208221153755, regulariztion_rates: 5.06497210548e-42, acc= 0.514
# learning_rate: 0.00712596492539, regulariztion_rates: 4.93719282511e-21, acc= 0.517
# learning_rate: 8.79099104099e-06, regulariztion_rates: 0.0113316179322, acc= 0.081
# Best Accuracy : 0.6

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.581

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
